# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scipy.optimize as opt

import json
import os
import sys
import tqdm
import time
import datetime

# %%
df_prices = pd.read_csv('../code/data/crypto.csv', index_col='dt', parse_dates=['dt'])
df_prices.drop('TON-USDT', axis=1, inplace=True)
df_prices.columns = [c.split('-')[0] for c in df_prices.columns]
df_prices
# Out:
#                          BTC      ETH    DOT    OKB      XRP     SOL      TRX  \
# dt
# 2020-01-01 19:00:00   7131.9   129.56    NaN    NaN  0.19050     NaN  0.01312
# 2020-01-02 19:00:00   7319.7   132.47    NaN    NaN  0.19203     NaN  0.01337
# 2020-01-03 19:00:00   7318.9   133.29    NaN    NaN  0.19249     NaN  0.01335
# 2020-01-04 19:00:00   7467.4   137.24    NaN    NaN  0.19628     NaN  0.01377
# 2020-01-05 19:00:00   7520.9   140.18    NaN    NaN  0.21275     NaN  0.01405
# ...                      ...      ...    ...    ...      ...     ...      ...
# 2024-12-27 19:00:00  94445.8  3368.12  6.947  53.83  2.17300  190.18  0.25690
# 2024-12-28 19:00:00  94504.1  3373.97  6.987  50.04  2.16450  195.12  0.26232
# 2024-12-29 19:00:00  92119.2  3323.88  6.613  49.57  2.02420  187.31  0.25108
# 2024-12-30 19:00:00  95413.9  3412.67  6.842  50.08  2.12860  198.42  0.25659
# 2024-12-31 19:00:00  94444.2  3353.19  6.801  48.52  2.22810  191.91  0.25512
#
#                         LTC
# ...

# %%
days_shift = 7
df_returns = df_prices.diff(days_shift) / df_prices.shift(days_shift)
df_returns = df_returns[df_returns.isna().sum(axis=1) == 0]

df_returns = df_returns[df_returns.index >= '2022-01-01']

n_observations, n_assets = df_returns.shape
print(n_observations, n_assets)


df_returns
# Out:
# 1095 8
#                           BTC       ETH       DOT       OKB       XRP  \
# dt
# 2022-01-01 19:00:00 -0.054014 -0.067913 -0.005263 -0.048031 -0.067994
# 2022-01-02 19:00:00 -0.092438 -0.075290 -0.067066 -0.070249 -0.103108
# 2022-01-03 19:00:00 -0.041478 -0.012844  0.008603 -0.035905 -0.054473
# 2022-01-04 19:00:00 -0.028151  0.006730  0.044412 -0.048068 -0.019920
# 2022-01-05 19:00:00 -0.088865 -0.083878 -0.050395 -0.093272 -0.089935
# ...                       ...       ...       ...       ...       ...
# 2024-12-27 19:00:00 -0.031560 -0.006595 -0.024435  0.189876 -0.037772
# 2024-12-28 19:00:00 -0.009079  0.021703  0.013931  0.110027 -0.024780
# 2024-12-29 19:00:00 -0.012196  0.014207 -0.036427  0.101556 -0.055569
# 2024-12-30 19:00:00 -0.029430 -0.023101 -0.095452  0.045511 -0.083172
# 2024-12-31 19:00:00 -0.041456 -0.034539 -0.087114  0.017617 -0.022463
#
#                           SOL       TRX       LTC
# dt
# 2022-01-01 19:00:00 -0.110254 -0.035776 -0.023856
# ...

# %%
df_returns.describe()
# Out:
#                BTC          ETH          DOT          OKB          XRP  \
# count  1095.000000  1095.000000  1095.000000  1095.000000  1095.000000
# mean      0.007286     0.003782    -0.003124     0.007685     0.013155
# std       0.077889     0.096069     0.111003     0.093618     0.132847
# min      -0.332838    -0.383014    -0.392469    -0.359057    -0.359555
# 25%      -0.035792    -0.047654    -0.072418    -0.040125    -0.050642
# 50%       0.002585    -0.001282    -0.008418    -0.001591    -0.000290
# 75%       0.044573     0.055515     0.057267     0.049402     0.042995
# max       0.356565     0.505611     0.618821     0.400260     1.023532
#
#                SOL          TRX          LTC
# count  1095.000000  1095.000000  1095.000000
# mean      0.011367     0.010538     0.002451
# std       0.148224     0.080004     0.100077
# min      -0.601772    -0.316207    -0.339202
# 25%      -0.076466    -0.023570    -0.051345
# 50%      -0.003390     0.010607     0.000141
# ...

# %%
import matplotlib.dates as mdates
import matplotlib.axis as maxis

# %%
plt.rcParams.update({'font.size': 12})

# %%
fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(12, 12), layout='constrained', sharex=True)
for c, ax in zip(df_prices.columns, axs.flatten()):
    ax.plot(df_prices[c])
    ax.set_title(c)
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
fig.savefig('../images/prices.png')

# %%
df_returns.describe().T
# Out:
#       count      mean       std       min       25%       50%       75%  \
# BTC  1095.0  0.007286  0.077889 -0.332838 -0.035792  0.002585  0.044573
# ETH  1095.0  0.003782  0.096069 -0.383014 -0.047654 -0.001282  0.055515
# DOT  1095.0 -0.003124  0.111003 -0.392469 -0.072418 -0.008418  0.057267
# OKB  1095.0  0.007685  0.093618 -0.359057 -0.040125 -0.001591  0.049402
# XRP  1095.0  0.013155  0.132847 -0.359555 -0.050642 -0.000290  0.042995
# SOL  1095.0  0.011367  0.148224 -0.601772 -0.076466 -0.003390  0.090647
# TRX  1095.0  0.010538  0.080004 -0.316207 -0.023570  0.010607  0.037312
# LTC  1095.0  0.002451  0.100077 -0.339202 -0.051345  0.000141  0.054629
#
#           max
# BTC  0.356565
# ETH  0.505611
# DOT  0.618821
# OKB  0.400260
# XRP  1.023532
# SOL  0.740882
# TRX  0.740697
# LTC  0.529393

# %%
df = df_returns.describe().T
fig, ax = plt.subplots(figsize=(6, 6))

for i, row in df.iterrows():
    ax.annotate(i, (row['std'], row['mean'] + 0.0003))

ax.scatter(df['std'], df['mean'])
ax.set_xlabel('Std ROI')
ax.set_ylabel('Mean ROI')
ax.set_xlim(0.05, 0.18)
ax.set_ylim(-0.005, 0.015)

fig.savefig('../images/rois_mean_std.png')

# %%
fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(6, 6), layout='constrained', sharex=True)
for c, ax in zip(df_returns.columns, axs.flatten()):
    ax.hist(df_returns[c], bins=15, density=True)
    ax.set_title(c)
    ax.yaxis.set_visible(False)
fig.savefig('../images/rois_hist.png')

# %%
# single assets
idx_most_risky = np.argmax(df_returns.describe().T['std'])
idx_less_risky = np.argmin(df_returns.describe().T['std'])
idx_best_return = np.argmax(df_returns.describe().T['mean'])
idx_worst_return = np.argmin(df_returns.describe().T['mean'])
idx_most_risky, idx_less_risky, idx_best_return, idx_worst_return
# Out:
# (5, 0, 4, 2)

# %%
class SingleAssetStrategy:
    def __init__(self, idx):
        self.idx = idx
    def fit(self, df_hist):
        self.name = df_hist.columns[self.idx].lower()
        if hasattr(self, 'w'):
            return self
        w = np.zeros(n_assets)        
        w[self.idx] = 1
        self.w = w
        return self
    def predict(self, df_hist):
        return self.w

# %%
class UniformStrategy:
    def __init__(self, top_n=None):
        self.top_n = top_n
        self.name = 'uniform' + ('' if top_n is None else f'_{top_n}')
    def fit(self, df_hist):
        if hasattr(self, 'w'):
            return self
        if self.top_n is None:
            self.w = np.full(n_assets, 1 / n_assets)
        else:
            rets = df_returns.mean(axis=0).values
            mask = np.where(np.argsort(rets) < self.top_n, 1, 0)
            self.w =  mask / mask.sum()
        return self
    def predict(self, df_hist):
        return self.w

# %%
def fixed_risk_max_return_optimizer(mu_hat, cov_hat, expected_risk):
    def objective(w):
        w = w.reshape((-1, 1))
        return -(w.T @ mu_hat).item()
    def unit_portfolio(w):
        return np.abs(w).sum() - 1
    def maximal_risk(w):
        w = w.reshape((-1, 1))
        return (expected_risk**2 - w.T @ cov_hat @ w).item()
    eq_cons = {
        'type': 'eq',
        'fun': unit_portfolio,
    }
    uneq_cons = {
        'type': 'ineq',
        'fun': maximal_risk,
    }
    bounds = [(-1, 1) for i in range(n_assets)]
    x0 = np.ones(n_assets) / n_assets
    sol = opt.minimize(
        fun=objective,
        x0=x0,
        method='SLSQP',
        bounds=bounds,
        constraints=[eq_cons, uneq_cons]
    )
    if sol.success:
        return sol.x

# %%
# сделать толще фронтиру
mu_hat = df_returns.mean(axis=0).values
cov_hat = df_returns.cov().values

param_grid = np.linspace(0.05, 0.7)
rets = []
risks = []
for param in param_grid:
    w = fixed_risk_max_return_optimizer(mu_hat, cov_hat, param)
    if w is None:
        continue
    w = w.reshape((-1, 1))
    rets.append((w.T @ mu_hat).item())
    risks.append((w.T @ cov_hat @ w).item() ** 0.5)
    
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(risks, rets)

df = df_returns.describe().T
ax.scatter(df['std'], df['mean'])

ax.set_xlabel('risk')
ax.set_ylabel('return')

ax.set_xlim(0.04, 0.18)
ax.set_ylim(-0.005, 0.015)

fig.savefig('../images/frontier.png')

# %%
class RandomPortfolio:
    def __init__(self, seed):
        np.random.seed(seed)
        self.name = f'random_{seed}'
    def fit(self, df_hist):
        w = np.random.randn(n_assets)
        w = w / np.abs(w).sum()
        self.w = w
        return self
    def predict(self, df_history):
        return self.w

# %%
class Naive_markowitz:
    def __init__(self, expected_risk):
        self.expected_rsk = expected_risk
        self.name = f'naive_markowitz_{self.expected_rsk:.4f}'
        
    def fit(self, df_history):
        self.mu_hat = df_history.mean(axis=0).values
        self.cov_hat = df_history.cov().values

        x = self._optimize_portfolio()
        self.w = x
        if x is None:
            print(self.name, 'not converged, setting zero portfolio')
            self.w = np.zeros(n_assets)
        return self
    
    def predict(self, df_history):
        return self.w
    
    def _optimize_portfolio(self):
        if self.expected_rsk is not None:
            return fixed_risk_max_return_optimizer(self.mu_hat, self.cov_hat, self.expected_rsk)

# %%
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima.model import ARIMA

# %%
class ARIMA_markowitz:
    def __init__(self, expected_risk, arima_order):
        self.expected_risk = expected_risk
        self.arima_order = arima_order
        self.name = f'arima_markowitz_{self.expected_risk:.4f}_{self.arima_order}'

    def fit(self, df_history):
        ar_models = [ARIMA(df_history[c], order=self.arima_order, freq='D').fit() for c in df_history.columns]
        pred_datetime = df_history.index[-1] + pd.Timedelta(days=days_shift)
        self.mu_hat = np.array([model.predict(start=pred_datetime, end=pred_datetime).item() for model in ar_models])
        self.cov_hat = df_history.cov().values
        
        x = self._optimize_portfolio()
        self.w = x
        if x is None:
            print(self.name, 'not converged, setting zero portfolio')
            self.w = np.zeros(n_assets)
        return self
    
    def predict(self, df_history):
        return self.w
    
    def _optimize_portfolio(self):
        if self.expected_risk is not None:
            return fixed_risk_max_return_optimizer(self.mu_hat, self.cov_hat, self.expected_risk)

# %%
import warnings
from statsmodels.tools.sm_exceptions import ValueWarning, ConvergenceWarning
warnings.simplefilter('ignore', ValueWarning)
warnings.simplefilter('ignore', ConvergenceWarning)
# warnings.simplefilter('ignore', UserWarning)

# %%
min_history_leng = 50

strategies = [
    SingleAssetStrategy(idx_most_risky),
    SingleAssetStrategy(idx_less_risky),
    SingleAssetStrategy(idx_best_return),
    SingleAssetStrategy(idx_worst_return),

    UniformStrategy(),
    UniformStrategy(3),
    UniformStrategy(5),

    RandomPortfolio(1),
    RandomPortfolio(2),
    RandomPortfolio(3),

    Naive_markowitz(0.01),
    Naive_markowitz(0.03),
    Naive_markowitz(0.05),
    Naive_markowitz(0.07),
    Naive_markowitz(0.10),
    
    ARIMA_markowitz(0.01, (1, 0, 1)),
    ARIMA_markowitz(0.03, (1, 0, 1)),
    ARIMA_markowitz(0.05, (1, 0, 1)),
    ARIMA_markowitz(0.07, (1, 0, 1)),
    ARIMA_markowitz(0.10, (1, 0, 1)),

    ARIMA_markowitz(0.01, (2, 1, 2)),
    ARIMA_markowitz(0.03, (2, 1, 2)),
    ARIMA_markowitz(0.05, (2, 1, 2)),
    ARIMA_markowitz(0.07, (2, 1, 2)),
    ARIMA_markowitz(0.10, (2, 1, 2)),
]

rois = []
total_runs = n_observations - days_shift - min_history_leng
print(total_runs)
for t in tqdm.trange(total_runs):
    idx_history = min_history_leng + t
    idx_future = idx_history + days_shift - 1

    df_history = df_returns.iloc[:idx_history]
    df_future = df_returns.iloc[idx_future]

    rois_per_strategy = []
    for strategy in strategies:
        if t % 7 == 0:
            strategy.fit(df_history)
        w = strategy.predict(df_history)
        roi = np.nan
        if np.isclose(np.abs(w).sum(), 1):
            roi = np.dot(w, df_future.values)
        rois_per_strategy.append(roi)
    rois.append(rois_per_strategy)

rois = pd.DataFrame(rois, columns=[s.name for s in strategies])
rois.to_csv(f'checkpoints\\{datetime.datetime.today().strftime("%Y-%m-%d-%H-%M-%S")}.csv', index=False)
# Out:
# 1038
#   0%|          | 0/1038 [00:00<?, ?it/s]
# C:\Users\tpolu\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\tpolu\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\tpolu\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ...

# %%
pd.DataFrame([s.w for s in strategies[10:]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.DataFrame([s.w for s in strategies[10:]])
#
# NameError: name 'pd' is not defined

# %%
rois.describe()
# Out:
#               sol         btc         sol         dot     uniform   uniform_3  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.080207   -0.027209    0.080207   -0.028157    0.023096   -0.006860
# std      0.231821    0.107194    0.231821    0.192756    0.182579    0.194889
# min     -0.525357   -0.328081   -0.525357   -0.610514   -0.516138   -0.521325
# 25%     -0.052859   -0.099090   -0.052859   -0.126801   -0.079502   -0.119985
# 50%      0.070977   -0.015419    0.070977   -0.007526    0.015347   -0.004189
# 75%      0.235940    0.040288    0.235940    0.098855    0.172505    0.096636
# max      0.662892    0.263731    0.662892    0.356776    0.353658    0.493639
#
#         uniform_5    random_1    random_2    random_3  naive_markowitz_0.0100  \
# count  100.000000  100.000000  100.000000  100.000000                     0.0
# mean     0.018377   -0.031322    0.012808   -0.033634                     NaN
# ...

# %%
fig, axs = plt.subplots(nrows=len(strategies), sharex=True, figsize=(6, 12), dpi=100)
for c, ax in zip(rois.columns, axs):
    ax.hist(rois[c])
    ax.set_title(c)
# Out:
# C:\Users\tpolu\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_axes.py:7065: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# C:\Users\tpolu\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_axes.py:7066: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 3
#       1 fig, axs = plt.subplots(nrows=len(strategies), sharex=True, figsize=(6, 12), dpi=100)
#       2 for c, ax in zip(rois.columns, axs):
# ----> 3     ax.hist(rois[c])
#       4     ax.set_title(c)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
# ...

# %%
means = rois.describe().T['mean']
stds = rois.describe().T['std']
plt.scatter(stds, means)

# %%
df_stats.index
# Out:
# Index(['xrp-usdt', 'btc-usdt', 'sol-usdt', 'ltc-usdt', 'uniform', 'uniform_3',
#        'uniform_5', 'random_1', 'random_2', 'random_3',
#        'naive_markowitz_0.0100', 'naive_markowitz_0.0300',
#        'naive_markowitz_0.0500', 'naive_markowitz_0.0700',
#        'naive_markowitz_0.1000', 'arima_markowitz_0.0100_(1, 0, 1)',
#        'arima_markowitz_0.0300_(1, 0, 1)', 'arima_markowitz_0.0500_(1, 0, 1)',
#        'arima_markowitz_0.0700_(1, 0, 1)', 'arima_markowitz_0.1000_(1, 0, 1)'],
#       dtype='object')

# %%
df_stats = rois.describe().T
means = df_stats['mean']
stds = df_stats['std']
# plt.scatter(stds, means)
means[['btc-usdt', 'xrp-usdt']]

single_asset_names = ['xrp-usdt', 'btc-usdt', 'sol-usdt', 'ltc-usdt']
trivial_names = ['uniform', 'uniform_3',
       'uniform_5', 'random_1', 'random_2', 'random_3']
naive_names = ['naive_markowitz_0.0100', 'naive_markowitz_0.0300',
       'naive_markowitz_0.0500', 'naive_markowitz_0.0700',
       'naive_markowitz_0.1000']
arima_names = ['arima_markowitz_0.0100_(1, 0, 1)',
       'arima_markowitz_0.0300_(1, 0, 1)', 'arima_markowitz_0.0500_(1, 0, 1)',
       'arima_markowitz_0.0700_(1, 0, 1)', 'arima_markowitz_0.1000_(1, 0, 1)']

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
for c, ax in zip([single_asset_names, trivial_names, naive_names, arima_names], axs.flatten()):
       means_blue = means[c]
       stds_blue = stds[c]

       means_grey = means.drop(c)
       stds_grey = stds.drop(c)
       
       ax.scatter(stds_grey, means_grey, c='grey')
       ax.scatter(stds_blue, means_blue, c='blue')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 5
#       3 stds = df_stats['std']
#       4 # plt.scatter(stds, means)
# ----> 5 means[['btc-usdt', 'xrp-usdt']]
#       7 single_asset_names = ['xrp-usdt', 'btc-usdt', 'sol-usdt', 'ltc-usdt']
#       8 trivial_names = ['uniform', 'uniform_3',
#       9        'uniform_5', 'random_1', 'random_2', 'random_3']
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\series.py:1153, in Series.__getitem__(self, key)
#    1150     key = np.asarray(key, dtype=bool)
#    1151     return self._get_rows_with_mask(key)
# -> 1153 return self._get_with(key)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\series.py:1194, in Series._get_with(self, key)
#    1191         return self.iloc[key]
#    1193 # handle the dup indexing case GH#4246
# -> 1194 return self.loc[key]
#
# ...

# %%
var_95 = rois.quantile(0.05).sort_values()
plt.barh(var_95.index, var_95.values)
plt.title('ROI Value at Risk (95%)')
# Out:
# Text(0.5, 1.0, 'ROI Value at Risk (95%)')
